# %% [markdown]
# <a href="https://colab.research.google.com/github/GillalaJeevana/Jeevana_INFO5502_Spring2022/blob/main/Jeevana_lab_assignment_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The fifth Lab-assignment (02/24/2022, 50 points in total)

# %% [markdown]
# The purpose of this exercise is to understand Data Visualization, we will practice how to create visualizations for different datasets bu using different tools.

# %% [markdown]
# Question 1 (15 points). In this questions, you will design a visualization for a small data set and provide a rigorous rationale for your design choices.
#
# Every 10 years, the census bureau documents the demographic make-up of the United States, influencing everything from congressional districting to social services. This dataset contains a high-level summary of census data for two years a century apart: 1900 and 2000. The data is a CSV (comma-separated values) file that describes the U.S. population in terms of year, reported sex (1: male, 2: female), age group (binned into 5 year segments from 0-4 years old up to 90+ years old), and the total count of people per group. There are 38 data points per year, for a total of 76 data points.
#
# You can download the dataset here:
#
# Dataset: https://github.com/unt-iialab/info5502-spring2022/blob/main/datasets/lab_assignment_05_census.csv
#
# Source: https://www.ipums.org/
#
# (1) Start by choosing a question you'd like a visualization to answer.
#
# (2) Generate a static visualization (i.e., a single image) that you believe effectively answers that question, and use the question as the title of your graphic.
#
# (3) Provide a short write-up (no more than 3 paragraphs) describing your design.
#
#
# While you must use the data set given, you are free to transform the data as you see fit. Such transforms may include (but are not limited to) log transformation, computing percentages or averages, grouping elements into new categories, or removing unnecessary variables or records. You are also free to incorporate external data as you see fit. Your chart image should be interpretable without recourse to your short write-up. Do not forget to include title, axis labels or legends as needed!
#
# As different visualizations can emphasize different aspects of a data set, you should document what aspects of the data you are attempting to most effectively communicate. In short, what story are you trying to tell? Just as important, also note which aspects of the data might be obscured or down-played due to your visualization design.
#
# In your write-up, you should provide a rigorous rationale for your design decisions. Document the visual encodings you used and why they are appropriate for the data and your specific question. These decisions include the choice of visualization type, size, color, scale, and other visual elements, as well as the use of sorting or other data transformations. How do these decisions facilitate effective communication?

# %% [markdown]
# #Answer for question 1:
#
# Question
# ....I would like to shown the population of different genders and diferent age groups....

# %%
# Your answer here (python code + explanation):
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("https://raw.githubusercontent.com/unt-iialab/info5502-spring2022/main/datasets/lab_assignment_05_census.csv", sep=",")
#plt.figure(figsize=(70,70))
#fig, ax = plt.subplots()
#plt.rcParams["figure.figsize"] = (40,40)
sns.barplot(data=df, x='Age', y='People', hue='Sex')
plt.ticklabel_format(style='plain', axis='y')

#sns.set(rc={'figure.figsize':(70,60)})
#sns.ticklabel_format(useOffset=False, style='plain', axis='y')
plt.show()

# %%
# Your answer here (interpretation of the results):

Design Strategy:
I imported the necessary libraries pandas, matplotlib
I used stacked bar chart to represent 3 attributes Age, People count, Gender of the people in the same plot.
Since the poeple population count is in billions, I used the tick label format method to format the population count in billions.
Plain style format is easy to understand.
It is observed that the population count of Sex 1 is higher until the age group 40.
And from the age group 45 and above, the population count of sex2 is higher than sex1.

# %% [markdown]
# Question 2 (20 points). In this question, you are required to use visualizations to tell a story about a dataset.
#
# Step 1. Pick a domain and data set that you are interested in.
#
# Peruse the provided data sets: http://nixdell.com/classes/HCI-and-Design-Spring-2016/Resources.html.
#
# Choose the one of greatest interest to you. If you would like to explore a different data set, you are free to do so but be aware of how much work might be needed to clean the data and get it into a usable format.
#
# Step 2. Explore the data. Find a story. Ask questions.
#
# Start by asking questions. For example: Is there a relationship between melting point and atomic number? Are the brightness and color of stars correlated? Are there different patterns of nucleotides in different regions in human DNA?
#
# Step 3. Assess the fitness of the data for answering your question.
#
# Inspect the data -- it is invariably helpful to first look at the raw values. Does the data seem appropriate for answering your question? If not, you may need to start the process over. If so, does the data need to be reformatted or cleaned prior to analysis? Perform any steps necessary to get the data into shape prior to visual analysis.
#
# Step 4. Create the visualization(s) that tell a story about the data.
#
# You will likely need to create several and see what works best. Keep a record of things you tried and discarded.

# %%
# Your answer here (python code + explanation):

#Loading libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib inline
#Loading the dataset for red wine and creating two new columns winetype and quality
red_wine = pd.read_csv("/content/winequality-red.csv")
red_wine['winetype']='red'
red_wine['quality_label'] = red_wine['quality'].apply(lambda value: 'low' 
                                                          if value <= 5 else 'medium' 
                                                              if value <= 7 else 'high')
red_wine['quality_label'] = pd.Categorical(red_wine['quality_label'], 
                                           categories=['low', 'medium', 'high'])
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality winetype quality_label
# 0      9.4        5      red           low
# 1      9.8        5      red           low
# 2      9.8        5      red           low
# 3      9.8        6      red        medium
# 4      9.4        5      red           low

# %%
#To know the number of rows and columns
wine.shape
# Out:
# (3198, 14)

# %%
#To know the column names
wine.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'winetype', 'quality_label'],
#       dtype='object')

# %%
#To know datatype of the attributes
wine.dtypes
# Out:
# fixed acidity            float64
# volatile acidity         float64
# citric acid              float64
# residual sugar           float64
# chlorides                float64
# free sulfur dioxide      float64
# total sulfur dioxide     float64
# density                  float64
# pH                       float64
# sulphates                float64
# alcohol                  float64
# quality                    int64
# winetype                  object
# quality_label           category
# dtype: object

# %%
#Plotting histogram
wine.hist(bins=10, color='lightblue', edgecolor='blue', linewidth=1.0,
              xlabelsize=8, ylabelsize=8, grid=False)    
plt.tight_layout(rect=(0, 0, 1.2, 1.2))

# %%
#Plotting heatmap
f, ax = plt.subplots(figsize=(10, 6))
b = sns.heatmap(wine.corr(), annot=True, linewidths=.05, ax=ax)
f.subplots_adjust(top=0.93)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
title= f.suptitle('Correlation Heatmap for wine attributes', fontsize=12)

# %%
#Joint plot
a = sns.jointplot("fixed acidity", "citric acid", data = wine, kind = 'reg', color = None)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Question 3 (15 points). In this question, you are required to create visualization for time series data.
#
# We have collected all the articles from AMIA in the last 30 years. The dataset is avaliable on GitHub: https://raw.githubusercontent.com/unt-iialab/info5502-spring2022/main/datasets/lab_assignment_05_amia_cleaned.csv.
#
# Please use the tool Yake: https://github.com/LIAAD/yake to extract the top N (you can set different N value to get the best visualization results) keywords from the article titles (all the articles), then visualize how the keywords changed over years in one figure. (Split the data by every five years)

# %%
# !pip install yake
# Out:
# Requirement already satisfied: yake in /usr/local/lib/python3.7/dist-packages (0.4.8)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from yake) (0.8.9)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from yake) (2.6.3)
# Requirement already satisfied: segtok in /usr/local/lib/python3.7/dist-packages (from yake) (1.5.11)
# Requirement already satisfied: jellyfish in /usr/local/lib/python3.7/dist-packages (from yake) (0.9.0)
# Requirement already satisfied: click>=6.0 in /usr/local/lib/python3.7/dist-packages (from yake) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from yake) (1.21.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from segtok->yake) (2019.12.20)

# %%
# Your python code here:

# Your python code here:

import pandas as pd
import matplotlib.pyplot as plt
import yake

df = pd.read_csv("https://raw.githubusercontent.com/unt-iialab/info5502-spring2022/main/datasets/lab_assignment_05_amia_cleaned.csv",
                 sep=",")
df
# Out:
#        pmc_id                                              title  \
# 0     8075400  Association of White Matter Hyperintensity Pro...
# 1     8075401  Mild Behavioral Impairment and Subjective Cogn...
# 2     8075402  Safety Monitoring of Gene Therapy for Spinal M...
# 3     8075403  Assessing the Progression of Alzheimer’s Disea...
# 4     8075404  Investigating the Spatial Associations Between...
# ...       ...                                                ...
# 5077  2581286  A Comparison of Models for Predicting the Outc...
# 5078  2581287            Impact of Computers on Nursing Research
# 5079  2581288  Microcomputer-Based Expert System for Clinical...
# 5080  2581289  Impact of Computers on Nursing Administration ...
# 5081  2581290  Medical Applications of a Spatial Data Managem...
#
#                               authors  \
# 0                       Kentaro Hirao
# 1                     Fumio Yamashita
# 2                       Akito Tsugawa
# 3                         Rieko Haime
# 4                      Raita Fukasawa
# ...                               ...
# 5077                Harriet H. Werley
# 5078  Donna L. HudsonandThelma Estrin
# 5079                 Virginia K. Saba
# 5080    Jane BarnettandDavid Kramlich
# 5081                William B. Hamlin
#
#                                     authors_information    year  \
# 0     aDepartment of Geriatric Medicine, Tokyo Medic...  2021.0
# 1     bDepartment of Ultrahigh Field MRI, Institute ...  2021.0
# 2     aDepartment of Psychiatry, University of Calga...  2021.0
# 3     bDepartment of Clinical Neurosciences, Univers...  2021.0
# 4     cDepartment of Community Health Sciences, Univ...  2021.0
# ...                                                 ...     ...
# 5077                                  Harriet H. Werley  1981.0
# 5078                    Donna L. HudsonandThelma Estrin  1981.0
# 5079                                   Virginia K. Saba  1981.0
# 5080                      Jane BarnettandDavid Kramlich  1981.0
# 5081                                  William B. Hamlin  1981.0
#
#                                                abstract
# 0     white matter hyperintensities wmh mri reported...
# 1     mild behavioral impairment mbi subjective cogn...
# 2     recently gene therapy onasemnogene abeparvovec...
# 3     exists considerable variation disease progress...
# 4     proposed amyloidβ aβ play causal role alzheime...
# ...                                                 ...
# 5077  several basic strategy may employed design new...
# 5078  microcomputerbased nuclear submarine ready fle...
# 5079  substantial portion record historical nature p...
# 5080  computeraided interactive game developed joint...
# 5081  automated quantitation uc fhr tabulated half h...
#
# [5082 rows x 6 columns]

# %%
df = df[df['year'].isna()!=True]
df['year'] = df['year'].astype('int64')
df.groupby(df['year']).head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        pmc_id                                              title  \
# 0     8075400  Association of White Matter Hyperintensity Pro...
# 1     8075401  Mild Behavioral Impairment and Subjective Cogn...
# 2     8075402  Safety Monitoring of Gene Therapy for Spinal M...
# 3     8075403  Assessing the Progression of Alzheimer’s Disea...
# 4     8075404  Investigating the Spatial Associations Between...
# ...       ...                                                ...
# 4965  2581174  Computer Use in Office and Ambulatory Practice...
# 4966  2581175  The Role of the Programmable Calculator in the...
# 4967  2581176     Month-at-a-Glance Ambulatory Scheduling System
# 4968  2581177  The Evolution of Ambulatory Medical Record Sys...
# 4969  2581178           Research Accounts Payable Control System
#
#                                 authors  \
# 0                         Kentaro Hirao
# 1                       Fumio Yamashita
# 2                         Akito Tsugawa
# 3                           Rieko Haime
# 4                        Raita Fukasawa
# ...                                 ...
# 4965                 Truman G. Schnabel
# 4966              P. WinnerandJ. Moller
# 4967                   George F. Timson
# 4968  Ingeborg M. KuhnandGio Wiederhold
# 4969                 Michael J. Distaso
#
#                                     authors_information  year  \
# 0     aDepartment of Geriatric Medicine, Tokyo Medic...  2021
# 1     bDepartment of Ultrahigh Field MRI, Institute ...  2021
# 2     aDepartment of Psychiatry, University of Calga...  2021
# 3     bDepartment of Clinical Neurosciences, Univers...  2021
# 4     cDepartment of Community Health Sciences, Univ...  2021
# ...                                                 ...   ...
# 4965                                 Truman G. Schnabel  1981
# 4966                              P. WinnerandJ. Moller  1981
# 4967                                   George F. Timson  1981
# 4968                  Ingeborg M. KuhnandGio Wiederhold  1981
# 4969                                 Michael J. Distaso  1981
#
#                                                abstract
# 0     white matter hyperintensities wmh mri reported...
# 1     mild behavioral impairment mbi subjective cogn...
# 2     recently gene therapy onasemnogene abeparvovec...
# 3     exists considerable variation disease progress...
# 4     proposed amyloidβ aβ play causal role alzheime...
# ...                                                 ...
# 4965  general approach establishment programmable ca...
# 4966  paper overview development automated ambulator...
# 4967  therapy relation disease relys adjustment diet...
# 4968  paper computer generated case summary us descr...
# 4969  paper concern application relational database ...
#
# [192 rows x 6 columns]

# %%
keywordDict = {}
for year in df['year'].unique():
    text = " ".join(title for title in df[df['year']==year]['title'].values)
    keyword_extractor = yake.KeywordExtractor(lan="en", 
                                                top=10,
                                                features=None)
    keywordDict[year] = keyword_extractor.extract_keywords(text)

# %%
keywordDict
# Out:
# {1981.0: [('Clinical Consultation Systems', 3.682359257232871e-05),
#   ('Hospital Information Systems', 3.924690678658242e-05),
#   ('System Information System', 4.437837486781911e-05),
#   ('Data Base Management', 4.575493129389773e-05),
#   ('Radiology Information Systems', 5.368204568809779e-05),
#   ('Information System Computers', 5.9355773934283234e-05),
#   ('Medical Information Systems', 6.001077672856754e-05),
#   ('Information System Bayesian', 6.496643087628623e-05),
#   ('Medical Data System', 6.555929113967357e-05),
#   ('Health Information System', 6.929720730600678e-05)],
#  1982.0: [('Medical Information System', 0.0002172731405936497),
#   ('Centralized Medical Data', 0.0002499628934406165),
#   ('Medical Data Base', 0.0002932529700873721),
#   ('Data Bases Medical', 0.0002932529700873721),
#   ('Clinical Data System', 0.0003574576831758086),
#   ('Data Base System', 0.00037311478442561373),
#   ('Pocket Medical Record', 0.00038588175374550836),
#   ('Data Base Management', 0.0003887834412215609),
#   ('Computerized Clinical Data', 0.0006377410052242117),
#   ('Medical Data Center', 0.0006443671880872059)],
#  1983.0: [('Based Morbidity Screening', 0.00013917288589446067),
#   ('Installing COSTAR Diagnosis', 0.00015005687923819),
#   ('Interpersonal Skills Assessment', 0.00015005687923819),
#   ('COSTAR Diagnosis Related', 0.00015874100717724247),
#   ('Diagnosis Related Groups', 0.00015874100717724247),
#   ('Radiological Image Processing', 0.00015874100717724247),
#   ('Image Processing Facility', 0.00015874100717724247),
#   ('Computerized Position Requisition', 0.00015874100717724247),
#   ('Structured Admissions Interview', 0.00015874100717724247),
#   ('Admissions Interview Process', 0.00015874100717724247)],
#  1985.0: [('Hospital Information System', 1.4986637071666723e-05),
#   ('Computerized Information Systems', 1.9615040591370405e-05),
#   ('Burn Information System', 2.231784211165467e-05),
#   ('Clinical Information System', 4.684397799622573e-05),
#   ('Library Information System', 5.2634281620567596e-05),
#   ('Medical Expert Systems', 6.188552081831581e-05),
#   ('Information System', 6.598835525882121e-05),
#   ('Information System Patient', 6.701163642656368e-05),
#   ('Patient Tracking System', 0.00010517309041999223),
#   ('Pharmacy Information System', 0.00010958901252202581)],
#  1986.0: [('Information Systems Medical', 3.18909381983885e-05),
#   ('Medical Information System', 3.189093819838851e-05),
#   ('Systems Medical Computers', 3.6479698432136135e-05),
#   ('Clinical Information System', 3.666145942175049e-05),
#   ('Information System Applications', 3.775208387634703e-05),
#   ('Hospital Information System', 4.3114519934180224e-05),
#   ('Computerized Medical Information', 4.4987321934508784e-05),
#   ('Based Systems Technology', 4.8101942117416374e-05),
#   ('Medical Computer Software', 4.8323012037676545e-05),
#   ('Knowledge Based Systems', 5.1050509304408415e-05)],
#  1987.0: [('Hospital Information System', 3.2709642794536677e-06),
#   ('Patient Information System', 1.1525170639989235e-05),
#   ('Laboratory Information System', 1.3298888292508859e-05),
#   ('Instructional Information Systems', 1.716921265971398e-05),
#   ('Networked Hospital Information', 1.7746827730216897e-05),
#   ('Care Information System', 1.990047392425627e-05),
#   ('Patient Care Information', 2.035956467112545e-05),
#   ('Distributed Information Systems', 2.037507792163444e-05),
#   ('Information System Distributed', 2.037507792163444e-05),
#   ('Nursing Information Systems', 2.19971506275984e-05)],
#  1988.0: [('Hospital Information System', 1.0282443459746488e-06),
#   ('Medical Knowledge Bases', 1.3737510305175832e-06),
#   ('Nursing Information Systems', 1.5568799892296442e-06),
#   ('Hospital Computer Systems', 4.540123226084061e-06),
#   ('Information System Network', 4.680061996224586e-06),
#   ('Laboratory Information Systems', 4.918741096965269e-06),
#   ('Expert Systems Development', 4.925975674785609e-06),
#   ('Medical Language System', 4.962019909068739e-06),
#   ('Expert Database Systems', 5.153979562032844e-06),
#   ('Computerized Expert Systems', 5.198081612802558e-06)],
#  1989.0: [('Medical Information System', 2.353177774924414e-06),
#   ('System Medical Knowledge', 2.453764517912236e-06),
#   ('Medical Expert Systems', 2.459231684753073e-06),
#   ('Hospital Information System', 2.5812712216898866e-06),
#   ('Clinical Information System', 2.855212678900917e-06),
#   ('Medical Knowledge Base', 3.2826392470668405e-06),
#   ('Database Management Systems', 3.845672259822504e-06),
#   ('Medical Language System', 4.161451434369629e-06),
#   ('Support Expert System', 4.798718050519523e-06),
#   ('Nursing Information System', 4.850125010151629e-06)],
#  1990.0: [('Clinical Information System', 1.629359996625945e-05),
#   ('Expert System Expert', 2.1354497973512238e-05),
#   ('System Expert Systems', 2.723306307000991e-05),
#   ('Hospital Information System', 2.886343693093988e-05),
#   ('Medical Expert System', 3.5228938717146165e-05),
#   ('Outpatient Clinical Information', 4.159431286750466e-05),
#   ('Statistical Expert Systems', 4.1804917829311185e-05),
#   ('Information Management System', 5.5318042650385314e-05),
#   ('Decision Support Systems', 6.678287319745363e-05),
#   ('Integrated Expert System', 6.734153564455702e-05)],
#  1991.0: [('information system', 0.0037458111137096384),
#   ('system', 0.003935040083529282),
#   ('Clinical Information System', 0.0041884112240754496),
#   ('medical', 0.004515516479419091),
#   ('medical information systems', 0.005465930105430284),
#   ('information', 0.008098994256238385),
#   ('hospital information system', 0.008719671862396234),
#   ('Medical Language System', 0.011348611179651337),
#   ('medical information', 0.013754938337870934),
#   ('Academic Information System', 0.0152571561150475)],
#  1992.0: [('system', 0.011694067440825557),
#   ('information', 0.017812114839015753),
#   ('medical', 0.020532055326711984),
#   ('clinical', 0.022772792357591016),
#   ('Information System', 0.03145758981565231),
#   ('systems', 0.03842336444842684),
#   ('data', 0.03972271637270634),
#   ('medical information systems', 0.04195614087669401),
#   ('patient', 0.04568369514226431),
#   ('Clinical Information System', 0.04758894407382146)],
#  1993.0: [('system', 0.011346611095627526),
#   ('patient', 0.019364715788148523),
#   ('information system', 0.021255008436181392),
#   ('expert system', 0.02567491842872248),
#   ('clinical information system', 0.026083180111765265),
#   ('medical', 0.026440035601779207),
#   ('consumers make informed', 0.026692097045992062),
#   ('care', 0.027431175779425172),
#   ('clinical', 0.02833772529915535),
#   ('patient record', 0.03277574056829587)],
#  1994.0: [('Catabolite Repression inSaccharomyces', 0.001185739112327361),
#   ('Quick Medical Reference', 0.0017227563341758298),
#   ('Repression inSaccharomyces cerevisiae', 0.00423756798314831),
#   ('kidney transplantation Accuracy', 0.004403943038652273),
#   ('Catabolite Repression', 0.00478180952256319),
#   ('Reference and Iliad', 0.004914120317027075),
#   ('Emulating cognitive diagnostic', 0.009876919448637582),
#   ('Renal cortex neuronal', 0.015603465077891808),
#   ('cortex neuronal nitric', 0.016233312889031782),
#   ('neuronal nitric oxide', 0.016233312889031782)],
#  1995.0: [('Support for information', 0.03491537602823697),
#   ('information management', 0.05695550697646169),
#   ('management in critical', 0.05695550697646169),
#   ('approach to identify', 0.05695550697646169),
#   ('critical care', 0.11635984525237528),
#   ('Support', 0.14533572323085503),
#   ('patient care setting', 0.14624082127698823),
#   ('care setting', 0.2000778483630907),
#   ('care', 0.22450676110568685),
#   ('information', 0.2321344025274505)],
#  1996.0: [('diabetic patient management', 0.021704381788440478),
#   ('intelligent data analysis', 0.0278850173298573),
#   ('World Wide Web', 0.036001085141224354),
#   ('information', 0.04184920162439905),
#   ('analysis in diabetic', 0.04326602853224161),
#   ('Web', 0.04747686048667469),
#   ('Natural Language Processing', 0.05610158026092168),
#   ('care', 0.06226796566204565),
#   ('Wide Web', 0.06856759791205307),
#   ('decision support', 0.07255670658651822)],
#  1997.0: [('merging multiple legacy', 0.008298133545729636),
#   ('multiple legacy databases', 0.008298133545729636),
#   ('Month Experience Nurses', 0.013947077011110502),
#   ('World Wide Web', 0.025948826170235653),
#   ('Electronic Mail Consultations', 0.03010246587004842),
#   ('merging multiple', 0.0358316211507357),
#   ('legacy databases', 0.0358316211507357),
#   ('clinical data repository', 0.03608606278970566),
#   ('multiple legacy', 0.04880013568230144),
#   ('enterprise-wide clinical data', 0.050351521851266234)],
#  1998.0: [('Efficiently Maintain', 0.0044853802797344584),
#   ('Maintain the Integrity', 0.0044853802797344584),
#   ('Knowledge Engineer Tool', 0.006451889478949837),
#   ('Electronic Medical Record', 0.008057086329034568),
#   ('stem-cell post-transplant long-term', 0.010080144942528879),
#   ('post-transplant long-term follow-up', 0.010080144942528879),
#   ('system', 0.014131705436553545),
#   ('computerized knowledge-support system', 0.014304352015067844),
#   ('Knowledge Engineer', 0.016035661213321846),
#   ('Knowledge Base', 0.016035661213321846)],
#  2000.0: [('European Commission DGXIII', 0.000272252694111577),
#   ('European Commission', 0.004316120368156304),
#   ('Commission DGXIII', 0.004316120368156304),
#   ('international integrated telemedicine', 0.01604861338565662),
#   ('Regional and international', 0.03068998858225639),
#   ('organ transplant', 0.03068998858225639),
#   ('Primary Care Model-based', 0.03409088994785989),
#   ('international integrated', 0.03483301078030752),
#   ('integrated telemedicine network', 0.038466822054002626),
#   ('Primary Care Research', 0.04273129492441601)],
#  2001.0: [('Fumaric acid production', 0.005061745688945959),
#   ('Accelerated Sodium Excretion', 0.006165537626766891),
#   ('Chronic Obstructive Pulmonary', 0.006182256063224477),
#   ('Rats Exhaled Breath', 0.006241849972989252),
#   ('Medical Record System', 0.0063098250907863635),
#   ('Docosahexaenoic Acid Ingestion', 0.0063733242320640655),
#   ('Arthritis Fumaric acid', 0.0063733242320640655),
#   ('ODS Rats Effect', 0.006610770265997074),
#   ('Chronic Kidney Disease', 0.007718115976373256),
#   ('High Sodium Intake', 0.007741559422189964)],
#  2002.0: [('Small Nuclear RNA', 4.533716702448886e-05),
#   ('Small Nucleolar RNAs', 4.8499234434415996e-05),
#   ('Mouse Liver Protein', 4.850940766215998e-05),
#   ('Small RNAs RNA', 5.038067915108716e-05),
#   ('Trypanosomatids Small Nucleolar', 5.0459623685532784e-05),
#   ('Small RNAs Reduces', 5.2417247174785525e-05),
#   ('Finger Proteins Involved', 5.2637406420694365e-05),
#   ('Analysis Genetic Analysis', 6.201214536816655e-05),
#   ('Nuclear RNA Transcription', 6.226933344078529e-05),
#   ('Lipoprotein Receptor Expression', 6.469005276327185e-05)],
#  2003.0: [('Physician Order Entry', 0.00011374216803451407),
#   ('electronic medical record', 0.00013087544518187668),
#   ('Decision support systems', 0.00014483392973911675),
#   ('Order Entry System', 0.00014692050681937774),
#   ('Clinical Decision Support', 0.00018610689276604984),
#   ('Computerized Physician Order', 0.00021311126228233782),
#   ('Clinical Information System', 0.00021626581264406764),
#   ('Care Support System', 0.00046094739507036283),
#   ('Record System Information', 0.0004894977642133144),
#   ('Medical Record Systems', 0.000497854575409382)],
#  2004.0: [('Direct IADL Measure', 0.00018550919338160987),
#   ('IADL Measure Detect', 0.00018550919338160987),
#   ('Measure Detect Deficits', 0.00018550919338160987),
#   ('Persons with MCI', 0.0027366367535859625),
#   ('Direct IADL', 0.003242916817013426),
#   ('IADL Measure', 0.003242916817013426),
#   ('Measure Detect', 0.003242916817013426),
#   ('Detect Deficits', 0.003242916817013426),
#   ('Deficits in Persons', 0.003242916817013426),
#   ('Scleroderma Editors’ Comments', 0.0048160834167583705)],
#  2005.0: [('Cape Verde kite', 0.00025011140746276786),
#   ('Prioritizing species conservation', 0.00039261605559303103),
#   ('Verde kite exist', 0.00039261605559303103),
#   ('bacterial microcosms Reputation', 0.00039325614922613316),
#   ('population dynamics Niches', 0.00040573608984469556),
#   ('paper wasp Genomic', 0.0004611085937925056),
#   ('wasp Genomic compatibility', 0.0004611085937925056),
#   ('Genomic compatibility occurs', 0.0004611085937925056),
#   ('outcrossing plant Aposematism', 0.0004611085937925056),
#   ('butterfly larva Nesting', 0.0004611085937925056)],
#  2006.0: [('Clinical Decision Support', 0.00022142285196463245),
#   ('Electronic Health Record', 0.00023344692117910072),
#   ('Electronic Medical Record', 0.00023349251964431428),
#   ('Health Information Technology', 0.00049075046485614),
#   ('Clinical Information Systems', 0.0005145436136128052),
#   ('Health Record System', 0.0005819583311432534),
#   ('medical record system', 0.0005820718888124698),
#   ('Health Record Data', 0.0006615173149524474),
#   ('Medical Record Data', 0.0006616464844181641),
#   ('Health Information Management', 0.0006645949120199033)],
#  2007.0: [('Clinical Decision Support', 6.901630054198732e-05),
#   ('Health Information Networks', 0.00014108693175946525),
#   ('Semantic Information Evaluation', 0.00021746640583485843),
#   ('Clinical Information System', 0.0002500090452666664),
#   ('Electronic Health Record', 0.0002889541892983093),
#   ('UMLS Semantic Network', 0.0003267575182523292),
#   ('Information Networks Assessing', 0.0003604666758281982),
#   ('Personal Health Records', 0.00044343967034796795),
#   ('decision support system', 0.0004895803348780193),
#   ('Health Information Exchanges', 0.0005349204667667722)],
#  2008.0: [('Electronic Medical Record', 9.814978853661262e-05),
#   ('Clinical Decision Support', 0.00010841516781293119),
#   ('health care system', 0.00012560900319540544),
#   ('Adding Medication Histories', 0.00016642588594728552),
#   ('Clinical Information Re-engineering', 0.0001816382460351286),
#   ('Electronic Health Records', 0.00018996293199198566),
#   ('Information Re-engineering Opportunities', 0.00019454929478624706),
#   ('Regenstrief Medication Hub', 0.0002150639727461214),
#   ('Medication Reconciliation Automatically', 0.0002150639727461214),
#   ('Hoc Clinical Questions', 0.00023127804165197027)],
#  2009.0: [('Clinical Information System', 8.663478018256873e-05),
#   ('Electronic Health Record', 8.795715462332605e-05),
#   ('Clinical Decision Support', 9.64073914063495e-05),
#   ('Electronic Medical Records', 0.00010117720212136771),
#   ('Peptide Subsidized Contraception', 0.0001721082999490163),
#   ('Hydrophilic Peptide Subsidized', 0.00017381389129345585),
#   ('White Hat Bias', 0.0002192910034444831),
#   ('Synthetic Polymer Nanoparticles', 0.00022146568776023153),
#   ('Health Record System', 0.00022418865630705558),
#   ('Electronic Health Information', 0.0002648448123453865)],
#  2010.0: [('Electronic Health Record', 1.9589701328866477e-05),
#   ('Clinical Decision Support', 4.074011859880352e-05),
#   ('Electronic Medical Record', 4.440277454346827e-05),
#   ('Natural Language Processing', 4.6436927116254096e-05),
#   ('Health Record Platform', 4.723153266946076e-05),
#   ('Integrating Direct Electronic', 5.211705931643818e-05),
#   ('Electronic Form Design', 6.418746272855622e-05),
#   ('Efficient Bayesian Method', 6.695248103887313e-05),
#   ('Direct Electronic Collection', 7.76722360659018e-05),
#   ('Health Information Technology', 8.24431789192882e-05)],
#  2011.0: [('Electronic Health Records', 0.0001234690584793154),
#   ('Health Information Exchange', 0.00018040444565526112),
#   ('Health Information Technology', 0.00023022224291144896),
#   ('Word Sequence Variation', 0.0002446245327589375),
#   ('Mild Traumatic Brain', 0.0002446245327589375),
#   ('Traumatic Brain Injury', 0.0002446245327589375),
#   ('Random Fields Understanding', 0.0002446245327589375),
#   ('Health Disclosure Laws', 0.0002677726140423243),
#   ('Electronic Medical Record', 0.0003004411233038199),
#   ('Corpus Derived Clinical', 0.0003021973770968719)],
#  2012.0: [('Electronic Health Record', 8.817363356549577e-05),
#   ('Clinical Decision Support', 0.00016119668153253639),
#   ('Ectomesenchymal Stem Cells', 0.00023347259904719488),
#   ('Invading Blood Vessels', 0.00028405076158728206),
#   ('Cytidine Deaminase DNA', 0.00028405076158728206),
#   ('Deaminase DNA Deamination', 0.00028405076158728206),
#   ('Health Information Exchange', 0.0003791561040241397),
#   ('Health Record Data', 0.0005659250549793638),
#   ('Records Patient clinical', 0.0006160127897309586),
#   ('Electronic Health', 0.0007155494553058434)],
#  2013.0: [('Electronic Health Records', 8.039173474025418e-05),
#   ('Sedentary Video Games', 0.0001602895927852689),
#   ('Health Information Exchange', 0.00018519702932145584),
#   ('City Clinical Practices', 0.00026148782418793147),
#   ('York City Clinical', 0.0003269866965643046),
#   ('Medical Home Practices', 0.00033335443471923495),
#   ('Electronic Medical Records', 0.0003852792523069921),
#   ('Activity-Promoting Video Game', 0.00047325308212205235),
#   ('Video Game compared', 0.00047325308212205235),
#   ('Health Care Users', 0.0005416854277231896)],
#  2014.0: [('Electronic Health Record', 4.562292192566021e-05),
#   ('Health Information Exchange', 5.420782457180507e-05),
#   ('Concept Annotation Problem', 8.786644287967464e-05),
#   ('Drug Labels Adapting', 9.17871650651575e-05),
#   ('Public Data Sets', 9.957486011615172e-05),
#   ('Data Sharing Preferences', 9.996002920111135e-05),
#   ('Clinical Data Repository', 0.00010374780593143271),
#   ('Health Record Data', 0.00011064305609800878),
#   ('FDA Drug Labels', 0.000115092353363865),
#   ('Department Staff Data', 0.00012485689726031806)],
#  2015.0: [('Arabidopsis DIFFERENTIAL EFFECTS', 0.00041690262896389407),
#   ('Clinical Decision Support', 0.0007840732574967832),
#   ('assembly Global Linking', 0.0007995193375016164),
#   ('Electronic Health Record', 0.0008516723171537783),
#   ('Electronic Clinical Quality', 0.0018101424755120072),
#   ('Italian Patients Effects', 0.0019033942867067372),
#   ('Electronic Medical Record', 0.001907526974134154),
#   ('Health Questions Patient', 0.0019362714797293902),
#   ('Laboratory Evaluation Effect', 0.00226926423820049),
#   ('Clinical', 0.002284144072666127)],
#  2016.0: [('Electronic Health Record', 2.2689299311951884e-05),
#   ('United States Modeling', 0.00010414447557390025),
#   ('Health Record Data', 0.00010517083557747467),
#   ('Clinical Study Data', 0.00011517188863694152),
#   ('Observational Clinical Data', 0.00011610479029870628),
#   ('State Parental Perceptions', 0.00012199276446352636),
#   ('York State Parental', 0.00012391283267629763),
#   ('Veteran Health Information', 0.0001311330582183004),
#   ('Clinical Data Elements', 0.00013597239239691657),
#   ('Data Elements Data', 0.00014411639430005706)],
#  2017.0: [('Electronic Health Records', 4.693710490219337e-05),
#   ('Traumatic Brain Injury', 0.00012854830297741464),
#   ('Spinal Cord Injury', 0.00015103458894308812),
#   ('Health Record Data', 0.00016685226707243488),
#   ('Measuring Workload Demand', 0.00019315619337791166),
#   ('Body Mass Index', 0.00019315619337791166),
#   ('Mining Electronic Health', 0.00020041080247386875),
#   ('Case Demand Index', 0.00021235177711684857),
#   ('Clinical Case Demand', 0.00021676177004103654),
#   ('Health Information Exchange', 0.00022528190088878593)],
#  2018.0: [('Electronic Health Record', 4.6324100014809876e-05),
#   ('Health Record Data', 0.00015349165693860474),
#   ('Clinical Decision Support', 0.0002037212929568448),
#   ('Feedback Intervention Theory', 0.00023105161943825071),
#   ('Engagement Consultation Service', 0.00023105161943825071),
#   ('Electronic Medical Record', 0.0002905483591147805),
#   ('Philippines Biophysical Analyses', 0.0002945370912531013),
#   ('Future Direction Defining', 0.0002945370912531013),
#   ('Extract Substance Abuse', 0.0002945370912531013),
#   ('Disordered Eating Adopt', 0.0002945370912531013)],
#  2019.0: [('Electronic Health Records', 0.00029651252878524245),
#   ('Clinical Decision Support', 0.0003827400207656758),
#   ('Clinical Data Research', 0.00045619220710452354),
#   ('Large Clinical Data', 0.0010522700915578465),
#   ('Data Research Network', 0.0010580968070820816),
#   ('Electronic Health', 0.0012007701027812445),
#   ('Distributed Health Data', 0.0012184728040130163),
#   ('Electronic Clinical Decision', 0.001309002544082113),
#   ('Catastrophic Antiphospholipid Syndrome', 0.0013981109967431038),
#   ('Antiphospholipid Syndrome Letter', 0.0013981109967431038)],
#  2020.0: [('Electronic Health Record', 0.00022547607734765726),
#   ('Densely Connected CNN', 0.0003234067444554375),
#   ('Hippocampus MRI Data', 0.0004083014470416426),
#   ('Identify Hospitalized Patients', 0.00042657502712225404),
#   ('Electronic Clinical Quality', 0.00044197789114759964),
#   ('Connected CNN Model', 0.00048283473131257226),
#   ('Clinical Quality Measure', 0.0005152518368886186),
#   ('Factors Affecting Stroke', 0.0006322964891184532),
#   ('deep learning Exploring', 0.0006388329243117043),
#   ('Deep Learning Health', 0.0006607537909498904)],
#  2021.0: [('Matter Hyperintensity Progression', 0.00013339348320859514),
#   ('Single Centre Experience', 0.00015642157558853453),
#   ('Centre Experience Assessing', 0.00015642157558853453),
#   ('Spinal Muscular Atrophy', 0.00018343650539378616),
#   ('European Countries Investigating', 0.00018343650539378616),
#   ('Social Leisure Activities', 0.00018343650539378616),
#   ('Leisure Activities Protective', 0.00018343650539378616),
#   ('Grey Matter Volume', 0.0002537897653699346),
#   ('White Matter Hyperintensity', 0.00027120469699506175),
#   ('Disease Current View', 0.00031366882345359656)],
#  nan: []}

# %%
for key, value in keywordDict.items():
  print(key)
  print(value)
# Out:
# 2021.0
# [('Matter Hyperintensity Progression', 0.00013339348320859514), ('Single Centre Experience', 0.00015642157558853453), ('Centre Experience Assessing', 0.00015642157558853453), ('Spinal Muscular Atrophy', 0.00018343650539378616), ('European Countries Investigating', 0.00018343650539378616), ('Social Leisure Activities', 0.00018343650539378616), ('Leisure Activities Protective', 0.00018343650539378616), ('Grey Matter Volume', 0.0002537897653699346), ('White Matter Hyperintensity', 0.00027120469699506175), ('Disease Current View', 0.00031366882345359656)]
# 2020.0
# [('Electronic Health Record', 0.00022547607734765726), ('Densely Connected CNN', 0.0003234067444554375), ('Hippocampus MRI Data', 0.0004083014470416426), ('Identify Hospitalized Patients', 0.00042657502712225404), ('Electronic Clinical Quality', 0.00044197789114759964), ('Connected CNN Model', 0.00048283473131257226), ('Clinical Quality Measure', 0.0005152518368886186), ('Factors Affecting Stroke', 0.0006322964891184532), ('deep learning Exploring', 0.0006388329243117043), ('Deep Learning Health', 0.0006607537909498904)]
# 2018.0
# [('Electronic Health Record', 4.6324100014809876e-05), ('Health Record Data', 0.00015349165693860474), ('Clinical Decision Support', 0.0002037212929568448), ('Feedback Intervention Theory', 0.00023105161943825071), ('Engagement Consultation Service', 0.00023105161943825071), ('Electronic Medical Record', 0.0002905483591147805), ('Philippines Biophysical Analyses', 0.0002945370912531013), ('Future Direction Defining', 0.0002945370912531013), ('Extract Substance Abuse', 0.0002945370912531013), ('Disordered Eating Adopt', 0.0002945370912531013)]
# 2015.0
# [('Arabidopsis DIFFERENTIAL EFFECTS', 0.00041690262896389407), ('Clinical Decision Support', 0.0007840732574967832), ('assembly Global Linking', 0.0007995193375016164), ('Electronic Health Record', 0.0008516723171537783), ('Electronic Clinical Quality', 0.0018101424755120072), ('Italian Patients Effects', 0.0019033942867067372), ('Electronic Medical Record', 0.001907526974134154), ('Health Questions Patient', 0.0019362714797293902), ('Laboratory Evaluation Effect', 0.00226926423820049), ('Clinical', 0.002284144072666127)]
# 2019.0
# [('Electronic Health Records', 0.00029651252878524245), ('Clinical Decision Support', 0.0003827400207656758), ('Clinical Data Research', 0.00045619220710452354), ('Large Clinical Data', 0.0010522700915578465), ('Data Research Network', 0.0010580968070820816), ('Electronic Health', 0.0012007701027812445), ('Distributed Health Data', 0.0012184728040130163), ('Electronic Clinical Decision', 0.001309002544082113), ('Catastrophic Antiphospholipid Syndrome', 0.0013981109967431038), ('Antiphospholipid Syndrome Letter', 0.0013981109967431038)]
# 2014.0
# [('Electronic Health Record', 4.562292192566021e-05), ('Health Information Exchange', 5.420782457180507e-05), ('Concept Annotation Problem', 8.786644287967464e-05), ('Drug Labels Adapting', 9.17871650651575e-05), ('Public Data Sets', 9.957486011615172e-05), ('Data Sharing Preferences', 9.996002920111135e-05), ('Clinical Data Repository', 0.00010374780593143271), ('Health Record Data', 0.00011064305609800878), ('FDA Drug Labels', 0.000115092353363865), ('Department Staff Data', 0.00012485689726031806)]
# 2016.0
# [('Electronic Health Record', 2.2689299311951884e-05), ('United States Modeling', 0.00010414447557390025), ('Health Record Data', 0.00010517083557747467), ('Clinical Study Data', 0.00011517188863694152), ('Observational Clinical Data', 0.00011610479029870628), ('State Parental Perceptions', 0.00012199276446352636), ('York State Parental', 0.00012391283267629763), ('Veteran Health Information', 0.0001311330582183004), ('Clinical Data Elements', 0.00013597239239691657), ('Data Elements Data', 0.00014411639430005706)]
# 2002.0
# [('Small Nuclear RNA', 4.533716702448886e-05), ('Small Nucleolar RNAs', 4.8499234434415996e-05), ('Mouse Liver Protein', 4.850940766215998e-05), ('Small RNAs RNA', 5.038067915108716e-05), ('Trypanosomatids Small Nucleolar', 5.0459623685532784e-05), ('Small RNAs Reduces', 5.2417247174785525e-05), ('Finger Proteins Involved', 5.2637406420694365e-05), ('Analysis Genetic Analysis', 6.201214536816655e-05), ('Nuclear RNA Transcription', 6.226933344078529e-05), ('Lipoprotein Receptor Expression', 6.469005276327185e-05)]
# 2017.0
# [('Electronic Health Records', 4.693710490219337e-05), ('Traumatic Brain Injury', 0.00012854830297741464), ('Spinal Cord Injury', 0.00015103458894308812), ('Health Record Data', 0.00016685226707243488), ('Measuring Workload Demand', 0.00019315619337791166), ('Body Mass Index', 0.00019315619337791166), ('Mining Electronic Health', 0.00020041080247386875), ('Case Demand Index', 0.00021235177711684857), ('Clinical Case Demand', 0.00021676177004103654), ('Health Information Exchange', 0.00022528190088878593)]
# 2012.0
# [('Electronic Health Record', 8.817363356549577e-05), ('Clinical Decision Support', 0.00016119668153253639), ('Ectomesenchymal Stem Cells', 0.00023347259904719488), ('Invading Blood Vessels', 0.00028405076158728206), ('Cytidine Deaminase DNA', 0.00028405076158728206), ('Deaminase DNA Deamination', 0.00028405076158728206), ('Health Information Exchange', 0.0003791561040241397), ('Health Record Data', 0.0005659250549793638), ('Records Patient clinical', 0.0006160127897309586), ('Electronic Health', 0.0007155494553058434)]
# 2013.0
# [('Electronic Health Records', 8.039173474025418e-05), ('Sedentary Video Games', 0.0001602895927852689), ('Health Information Exchange', 0.00018519702932145584), ('City Clinical Practices', 0.00026148782418793147), ('York City Clinical', 0.0003269866965643046), ('Medical Home Practices', 0.00033335443471923495), ('Electronic Medical Records', 0.0003852792523069921), ('Activity-Promoting Video Game', 0.00047325308212205235), ('Video Game compared', 0.00047325308212205235), ('Health Care Users', 0.0005416854277231896)]
# 2011.0
# [('Electronic Health Records', 0.0001234690584793154), ('Health Information Exchange', 0.00018040444565526112), ('Health Information Technology', 0.00023022224291144896), ('Word Sequence Variation', 0.0002446245327589375), ('Mild Traumatic Brain', 0.0002446245327589375), ('Traumatic Brain Injury', 0.0002446245327589375), ('Random Fields Understanding', 0.0002446245327589375), ('Health Disclosure Laws', 0.0002677726140423243), ('Electronic Medical Record', 0.0003004411233038199), ('Corpus Derived Clinical', 0.0003021973770968719)]
# 2007.0
# [('Clinical Decision Support', 6.901630054198732e-05), ('Health Information Networks', 0.00014108693175946525), ('Semantic Information Evaluation', 0.00021746640583485843), ('Clinical Information System', 0.0002500090452666664), ('Electronic Health Record', 0.0002889541892983093), ('UMLS Semantic Network', 0.0003267575182523292), ('Information Networks Assessing', 0.0003604666758281982), ('Personal Health Records', 0.00044343967034796795), ('decision support system', 0.0004895803348780193), ('Health Information Exchanges', 0.0005349204667667722)]
# 2010.0
# [('Electronic Health Record', 1.9589701328866477e-05), ('Clinical Decision Support', 4.074011859880352e-05), ('Electronic Medical Record', 4.440277454346827e-05), ('Natural Language Processing', 4.6436927116254096e-05), ('Health Record Platform', 4.723153266946076e-05), ('Integrating Direct Electronic', 5.211705931643818e-05), ('Electronic Form Design', 6.418746272855622e-05), ('Efficient Bayesian Method', 6.695248103887313e-05), ('Direct Electronic Collection', 7.76722360659018e-05), ('Health Information Technology', 8.24431789192882e-05)]
# 2008.0
# [('Electronic Medical Record', 9.814978853661262e-05), ('Clinical Decision Support', 0.00010841516781293119), ('health care system', 0.00012560900319540544), ('Adding Medication Histories', 0.00016642588594728552), ('Clinical Information Re-engineering', 0.0001816382460351286), ('Electronic Health Records', 0.00018996293199198566), ('Information Re-engineering Opportunities', 0.00019454929478624706), ('Regenstrief Medication Hub', 0.0002150639727461214), ('Medication Reconciliation Automatically', 0.0002150639727461214), ('Hoc Clinical Questions', 0.00023127804165197027)]
# 2009.0
# [('Clinical Information System', 8.663478018256873e-05), ('Electronic Health Record', 8.795715462332605e-05), ('Clinical Decision Support', 9.64073914063495e-05), ('Electronic Medical Records', 0.00010117720212136771), ('Peptide Subsidized Contraception', 0.0001721082999490163), ('Hydrophilic Peptide Subsidized', 0.00017381389129345585), ('White Hat Bias', 0.0002192910034444831), ('Synthetic Polymer Nanoparticles', 0.00022146568776023153), ('Health Record System', 0.00022418865630705558), ('Electronic Health Information', 0.0002648448123453865)]
# 2004.0
# [('Direct IADL Measure', 0.00018550919338160987), ('IADL Measure Detect', 0.00018550919338160987), ('Measure Detect Deficits', 0.00018550919338160987), ('Persons with MCI', 0.0027366367535859625), ('Direct IADL', 0.003242916817013426), ('IADL Measure', 0.003242916817013426), ('Measure Detect', 0.003242916817013426), ('Detect Deficits', 0.003242916817013426), ('Deficits in Persons', 0.003242916817013426), ('Scleroderma Editors’ Comments', 0.0048160834167583705)]
# 2006.0
# [('Clinical Decision Support', 0.00022142285196463245), ('Electronic Health Record', 0.00023344692117910072), ('Electronic Medical Record', 0.00023349251964431428), ('Health Information Technology', 0.00049075046485614), ('Clinical Information Systems', 0.0005145436136128052), ('Health Record System', 0.0005819583311432534), ('medical record system', 0.0005820718888124698), ('Health Record Data', 0.0006615173149524474), ('Medical Record Data', 0.0006616464844181641), ('Health Information Management', 0.0006645949120199033)]
# 2005.0
# [('Cape Verde kite', 0.00025011140746276786), ('Prioritizing species conservation', 0.00039261605559303103), ('Verde kite exist', 0.00039261605559303103), ('bacterial microcosms Reputation', 0.00039325614922613316), ('population dynamics Niches', 0.00040573608984469556), ('paper wasp Genomic', 0.0004611085937925056), ('wasp Genomic compatibility', 0.0004611085937925056), ('Genomic compatibility occurs', 0.0004611085937925056), ('outcrossing plant Aposematism', 0.0004611085937925056), ('butterfly larva Nesting', 0.0004611085937925056)]
# 2003.0
# [('Physician Order Entry', 0.00011374216803451407), ('electronic medical record', 0.00013087544518187668), ('Decision support systems', 0.00014483392973911675), ('Order Entry System', 0.00014692050681937774), ('Clinical Decision Support', 0.00018610689276604984), ('Computerized Physician Order', 0.00021311126228233782), ('Clinical Information System', 0.00021626581264406764), ('Care Support System', 0.00046094739507036283), ('Record System Information', 0.0004894977642133144), ('Medical Record Systems', 0.000497854575409382)]
# 2001.0
# [('Fumaric acid production', 0.005061745688945959), ('Accelerated Sodium Excretion', 0.006165537626766891), ('Chronic Obstructive Pulmonary', 0.006182256063224477), ('Rats Exhaled Breath', 0.006241849972989252), ('Medical Record System', 0.0063098250907863635), ('Docosahexaenoic Acid Ingestion', 0.0063733242320640655), ('Arthritis Fumaric acid', 0.0063733242320640655), ('ODS Rats Effect', 0.006610770265997074), ('Chronic Kidney Disease', 0.007718115976373256), ('High Sodium Intake', 0.007741559422189964)]
# 2000.0
# [('European Commission DGXIII', 0.000272252694111577), ('European Commission', 0.004316120368156304), ('Commission DGXIII', 0.004316120368156304), ('international integrated telemedicine', 0.01604861338565662), ('Regional and international', 0.03068998858225639), ('organ transplant', 0.03068998858225639), ('Primary Care Model-based', 0.03409088994785989), ('international integrated', 0.03483301078030752), ('integrated telemedicine network', 0.038466822054002626), ('Primary Care Research', 0.04273129492441601)]
# 1998.0
# [('Efficiently Maintain', 0.0044853802797344584), ('Maintain the Integrity', 0.0044853802797344584), ('Knowledge Engineer Tool', 0.006451889478949837), ('Electronic Medical Record', 0.008057086329034568), ('stem-cell post-transplant long-term', 0.010080144942528879), ('post-transplant long-term follow-up', 0.010080144942528879), ('system', 0.014131705436553545), ('computerized knowledge-support system', 0.014304352015067844), ('Knowledge Engineer', 0.016035661213321846), ('Knowledge Base', 0.016035661213321846)]
# nan
# []
# 1996.0
# [('diabetic patient management', 0.021704381788440478), ('intelligent data analysis', 0.0278850173298573), ('World Wide Web', 0.036001085141224354), ('information', 0.04184920162439905), ('analysis in diabetic', 0.04326602853224161), ('Web', 0.04747686048667469), ('Natural Language Processing', 0.05610158026092168), ('care', 0.06226796566204565), ('Wide Web', 0.06856759791205307), ('decision support', 0.07255670658651822)]
# 1997.0
# [('merging multiple legacy', 0.008298133545729636), ('multiple legacy databases', 0.008298133545729636), ('Month Experience Nurses', 0.013947077011110502), ('World Wide Web', 0.025948826170235653), ('Electronic Mail Consultations', 0.03010246587004842), ('merging multiple', 0.0358316211507357), ('legacy databases', 0.0358316211507357), ('clinical data repository', 0.03608606278970566), ('multiple legacy', 0.04880013568230144), ('enterprise-wide clinical data', 0.050351521851266234)]
# 1995.0
# [('Support for information', 0.03491537602823697), ('information management', 0.05695550697646169), ('management in critical', 0.05695550697646169), ('approach to identify', 0.05695550697646169), ('critical care', 0.11635984525237528), ('Support', 0.14533572323085503), ('patient care setting', 0.14624082127698823), ('care setting', 0.2000778483630907), ('care', 0.22450676110568685), ('information', 0.2321344025274505)]
# 1991.0
# [('information system', 0.0037458111137096384), ('system', 0.003935040083529282), ('Clinical Information System', 0.0041884112240754496), ('medical', 0.004515516479419091), ('medical information systems', 0.005465930105430284), ('information', 0.008098994256238385), ('hospital information system', 0.008719671862396234), ('Medical Language System', 0.011348611179651337), ('medical information', 0.013754938337870934), ('Academic Information System', 0.0152571561150475)]
# 1994.0
# [('Catabolite Repression inSaccharomyces', 0.001185739112327361), ('Quick Medical Reference', 0.0017227563341758298), ('Repression inSaccharomyces cerevisiae', 0.00423756798314831), ('kidney transplantation Accuracy', 0.004403943038652273), ('Catabolite Repression', 0.00478180952256319), ('Reference and Iliad', 0.004914120317027075), ('Emulating cognitive diagnostic', 0.009876919448637582), ('Renal cortex neuronal', 0.015603465077891808), ('cortex neuronal nitric', 0.016233312889031782), ('neuronal nitric oxide', 0.016233312889031782)]
# 1993.0
# [('system', 0.011346611095627526), ('patient', 0.019364715788148523), ('information system', 0.021255008436181392), ('expert system', 0.02567491842872248), ('clinical information system', 0.026083180111765265), ('medical', 0.026440035601779207), ('consumers make informed', 0.026692097045992062), ('care', 0.027431175779425172), ('clinical', 0.02833772529915535), ('patient record', 0.03277574056829587)]
# 1992.0
# [('system', 0.011694067440825557), ('information', 0.017812114839015753), ('medical', 0.020532055326711984), ('clinical', 0.022772792357591016), ('Information System', 0.03145758981565231), ('systems', 0.03842336444842684), ('data', 0.03972271637270634), ('medical information systems', 0.04195614087669401), ('patient', 0.04568369514226431), ('Clinical Information System', 0.04758894407382146)]
# 1990.0
# [('Clinical Information System', 1.629359996625945e-05), ('Expert System Expert', 2.1354497973512238e-05), ('System Expert Systems', 2.723306307000991e-05), ('Hospital Information System', 2.886343693093988e-05), ('Medical Expert System', 3.5228938717146165e-05), ('Outpatient Clinical Information', 4.159431286750466e-05), ('Statistical Expert Systems', 4.1804917829311185e-05), ('Information Management System', 5.5318042650385314e-05), ('Decision Support Systems', 6.678287319745363e-05), ('Integrated Expert System', 6.734153564455702e-05)]
# 1989.0
# [('Medical Information System', 2.353177774924414e-06), ('System Medical Knowledge', 2.453764517912236e-06), ('Medical Expert Systems', 2.459231684753073e-06), ('Hospital Information System', 2.5812712216898866e-06), ('Clinical Information System', 2.855212678900917e-06), ('Medical Knowledge Base', 3.2826392470668405e-06), ('Database Management Systems', 3.845672259822504e-06), ('Medical Language System', 4.161451434369629e-06), ('Support Expert System', 4.798718050519523e-06), ('Nursing Information System', 4.850125010151629e-06)]
# 1988.0
# [('Hospital Information System', 1.0282443459746488e-06), ('Medical Knowledge Bases', 1.3737510305175832e-06), ('Nursing Information Systems', 1.5568799892296442e-06), ('Hospital Computer Systems', 4.540123226084061e-06), ('Information System Network', 4.680061996224586e-06), ('Laboratory Information Systems', 4.918741096965269e-06), ('Expert Systems Development', 4.925975674785609e-06), ('Medical Language System', 4.962019909068739e-06), ('Expert Database Systems', 5.153979562032844e-06), ('Computerized Expert Systems', 5.198081612802558e-06)]
# 1987.0
# [('Hospital Information System', 3.2709642794536677e-06), ('Patient Information System', 1.1525170639989235e-05), ('Laboratory Information System', 1.3298888292508859e-05), ('Instructional Information Systems', 1.716921265971398e-05), ('Networked Hospital Information', 1.7746827730216897e-05), ('Care Information System', 1.990047392425627e-05), ('Patient Care Information', 2.035956467112545e-05), ('Distributed Information Systems', 2.037507792163444e-05), ('Information System Distributed', 2.037507792163444e-05), ('Nursing Information Systems', 2.19971506275984e-05)]
# 1986.0
# [('Information Systems Medical', 3.18909381983885e-05), ('Medical Information System', 3.189093819838851e-05), ('Systems Medical Computers', 3.6479698432136135e-05), ('Clinical Information System', 3.666145942175049e-05), ('Information System Applications', 3.775208387634703e-05), ('Hospital Information System', 4.3114519934180224e-05), ('Computerized Medical Information', 4.4987321934508784e-05), ('Based Systems Technology', 4.8101942117416374e-05), ('Medical Computer Software', 4.8323012037676545e-05), ('Knowledge Based Systems', 5.1050509304408415e-05)]
# 1985.0
# [('Hospital Information System', 1.4986637071666723e-05), ('Computerized Information Systems', 1.9615040591370405e-05), ('Burn Information System', 2.231784211165467e-05), ('Clinical Information System', 4.684397799622573e-05), ('Library Information System', 5.2634281620567596e-05), ('Medical Expert Systems', 6.188552081831581e-05), ('Information System', 6.598835525882121e-05), ('Information System Patient', 6.701163642656368e-05), ('Patient Tracking System', 0.00010517309041999223), ('Pharmacy Information System', 0.00010958901252202581)]
# 1983.0
# [('Based Morbidity Screening', 0.00013917288589446067), ('Installing COSTAR Diagnosis', 0.00015005687923819), ('Interpersonal Skills Assessment', 0.00015005687923819), ('COSTAR Diagnosis Related', 0.00015874100717724247), ('Diagnosis Related Groups', 0.00015874100717724247), ('Radiological Image Processing', 0.00015874100717724247), ('Image Processing Facility', 0.00015874100717724247), ('Computerized Position Requisition', 0.00015874100717724247), ('Structured Admissions Interview', 0.00015874100717724247), ('Admissions Interview Process', 0.00015874100717724247)]
# 1982.0
# [('Medical Information System', 0.0002172731405936497), ('Centralized Medical Data', 0.0002499628934406165), ('Medical Data Base', 0.0002932529700873721), ('Data Bases Medical', 0.0002932529700873721), ('Clinical Data System', 0.0003574576831758086), ('Data Base System', 0.00037311478442561373), ('Pocket Medical Record', 0.00038588175374550836), ('Data Base Management', 0.0003887834412215609), ('Computerized Clinical Data', 0.0006377410052242117), ('Medical Data Center', 0.0006443671880872059)]
# 1981.0
# [('Clinical Consultation Systems', 3.682359257232871e-05), ('Hospital Information Systems', 3.924690678658242e-05), ('System Information System', 4.437837486781911e-05), ('Data Base Management', 4.575493129389773e-05), ('Radiology Information Systems', 5.368204568809779e-05), ('Information System Computers', 5.9355773934283234e-05), ('Medical Information Systems', 6.001077672856754e-05), ('Information System Bayesian', 6.496643087628623e-05), ('Medical Data System', 6.555929113967357e-05), ('Health Information System', 6.929720730600678e-05)]
